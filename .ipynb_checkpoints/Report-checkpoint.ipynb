# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
print(df.head())
print(df.info())
# Out:
#                                     Job Name  \
# 0  Բուժքույր ստոմատոլոգիական կլինիկայի համար
# 1                              Ադմինիստրատոր
# 2                               Tour Manager
# 3                               Receptionist
# 4         Tech lead of product teams (Tribe)
#
#                                  Company       Deadline Location
# 0  Ավանտա նորարարական բժշկության կենտրոն  22 April 2024  Yerevan
# 1  Ավանտա նորարարական բժշկության կենտրոն  22 April 2024  Yerevan
# 2                             ՌԵՎԵԼ ՏՈՒՐ  22 April 2024   Gyumri
# 3                   Skyline Tour Service  21 April 2024  Yerevan
# 4                        Ameriabank CJSC  04 April 2024  Yerevan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1317 entries, 0 to 1316
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Job Name  1317 non-null   object
#  1   Company   1317 non-null   object
#  2   Deadline  1317 non-null   object
#  3   Location  1317 non-null   object
# dtypes: object(4)
# memory usage: 41.3+ KB
# None

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
company_jobs = df['Company'].value_counts()
print(company_jobs)
# Out:
# Company
# SoftConstruct                               54
# Digitain                                    51
# FastBank CJSC                               26
# VTB Bank (Armenia)                          25
# Ameriabank CJSC                             24
#                                             ..
# Prokat.am                                    1
# Ֆրիվեյ Ֆայնանս ՓԲԸ                           1
# Caucasus Research Resource Center (CRRC)     1
# Zangak Publishing House                      1
# Էվրի Դեյ ՓԲԸ                                 1
# Name: count, Length: 486, dtype: int64

# %%
job_locations = df['Location'].value_counts()
print(job_locations)
# Out:
# Location
# Yerevan                                                                     1109
# Yerevan                                            (Remote)                   37
# Arzni                                                                         13
# Abovyan                                                                       12
# Gyumri                                                                        11
# Ashtarak                                                                       6
# Charentsavan                                                                   6
# Ararat                                                                         5
# Hrazdan                                                                        5
# Artashat                                                                       4
# Tsaghkadzor                                                                    3
# Yeghegnadzor                                                                   3
# Martuni                                                                        3
# Vagharshapat                                                                   3
# Goris                                                                          3
# Vardenis                                                                       3
# Masis                                                                          3
# Talin                                                                          3
# Jermuk                                                                         2
# Kapan                                                                          2
# Meghri                                                                         2
# Armavir                                                                        2
# Hankavan                                                                       2
# Las Vegas                                            (Remote)                  2
# Kajaran                                                                        2
# Armenia (All cities)                                            (Remote)       2
# Northampton                                            (Remote)                1
# Gavar                                                                          1
# Sevan                                                                          1
# Yeghvard                                                                       1
# Vanadzor                                                                       1
# Dilijan                                                                        1
# Bagratashen                                                                    1
# Artik                                                                          1
# Ashdod                                            (Remote)                     1
# Nor Hachn                                                                      1
# Ijevan                                                                         1
# Spitak                                                                         1
# Aparan                                                                         1
# village Kotayk                                                                 1
# Vedi                                                                           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
job_locations.plot(kind='bar')
plt.title('Distribution of Job Locations')
plt.xlabel('Location')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=45)
plt.show()

# %%
avg_jobs_per_company = round(company_jobs.mean(), 2)
print("Average number of jobs posted by each company:", avg_jobs_per_company)

job_types = df['Job Name'].value_counts()
print("Distribution of job types:")
print(job_types)
# Out:
# Average number of jobs posted by each company: 2.6
# Distribution of job types:
# Job Name
# Accountant                                    18
# Հաշվետար                                      10
# Հաշվապահ                                       8
# Sales Specialist                               7
# SMM Specialist                                 7
#                                               ..
# Jira Administrator                             1
# Problem Manager                                1
# Change Management Specialist                   1
# Change and Release Management Unit Manager     1
# Ֆիրմային խանութների պատասխանատու               1
# Name: count, Length: 1073, dtype: int64
